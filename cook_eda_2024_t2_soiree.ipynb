# %%
import pandas as pd
from tqdm.notebook import tqdm
import datetime

# %%
base = 'https://www.resultats-elections.interieur.gouv.fr/telechargements/LG2024'

# %%
circonscriptions = pd.read_csv('lg2024_circonscriptions.csv')

# %%
mapping_dept = (
    pd
    .read_csv('lg2022_circonscriptions.csv')
    .groupby(['CodDpt3Car', 'CodDpt'])
    .agg({'CodCirLg': len})
    .reset_index()
    .set_index('CodDpt3Car')
    [['CodDpt']]
    .query('CodDpt.str.startswith("Z")')
    .to_dict()
    ['CodDpt']
)

mapping_dept
# Out:
# {'099': 'ZZ',
#  '971': 'ZA',
#  '972': 'ZB',
#  '973': 'ZC',
#  '974': 'ZD',
#  '975': 'ZS',
#  '976': 'ZM',
#  '977': 'ZX',
#  '986': 'ZW',
#  '987': 'ZP',
#  '988': 'ZN'}

# %%
t1_resultats = (
    pd
    .read_csv('lg2024/t1_resultats.csv')
)

t1_resultats
# Out:
#       NumPanneauCand     NomPsn     PrenomPsn CivilitePsn CodNuaCand  \
# 0                  1  LENORMAND      Stéphane          M.        DVD
# 1                  2   BEAUMONT      Frédéric          M.        SOC
# 2                  3    CHAGNON      Patricia         Mme         RN
# 3                  4  LETOURNEL        Marion         Mme         FI
# 4                  5   LEBAILLY       Patrick          M.        DVG
# ...              ...        ...           ...         ...        ...
# 4004               4   RONGIONE       Viviane         Mme        EXG
# 4005               5    GIACOMI  Jean-Antoine          M.        REG
# 4006               6     JOUART        Sylvie         Mme         RN
# 4007               7      CARLI          Antò          M.        REG
# 4008               8    SANCHEZ        Hélène         Mme        VEC
#
#                   LibNuaCand  NbVoix RapportExprimes RapportInscrits  \
# 0              Divers droite    1184           43,09           23,36
# 1           Parti socialiste     464           16,89            9,15
# 2     Rassemblement National     291           10,59            5,74
# 3        La France insoumise     409           14,88            8,07
# 4              Divers gauche     400           14,56            7,89
# ...                      ...     ...             ...             ...
# 4004          Extrême gauche     280            0,63            0,41
# 4005            Régionaliste       0            0,00            0,00
# 4006  Rassemblement National   11275           25,42           16,60
# 4007            Régionaliste    2277            5,13            3,35
# 4008         Les Ecologistes    2668            6,02            3,93
#
#             Elu CodCirc CodDept  CodeReg                LibCirElec  NbSap  \
# 0     QUALIF T2   97501     975        0  Saint-Pierre-et-Miquelon      1
# 1     QUALIF T2   97501     975        0  Saint-Pierre-et-Miquelon      1
# 2           NON   97501     975        0  Saint-Pierre-et-Miquelon      1
# 3           NON   97501     975        0  Saint-Pierre-et-Miquelon      1
# 4           NON   97501     975        0  Saint-Pierre-et-Miquelon      1
# ...         ...     ...     ...      ...                       ...    ...
# 4004        NON    2B02      2B       94      2ème circonscription      1
# 4005        NON    2B02      2B       94      2ème circonscription      1
# 4006  QUALIF T2    2B02      2B       94      2ème circonscription      1
# 4007        NON    2B02      2B       94      2ème circonscription      1
# 4008        NON    2B02      2B       94      2ème circonscription      1
#
#       CodReg CodDpt CodCirc2
# 0          0    975    ZS001
# 1          0    975    ZS001
# 2          0    975    ZS001
# 3          0    975    ZS001
# 4          0    975    ZS001
# ...      ...    ...      ...
# 4004      94     2B    2B002
# 4005      94     2B    2B002
# 4006      94     2B    2B002
# 4007      94     2B    2B002
# 4008      94     2B    2B002
#
# [4009 rows x 18 columns]

# %%
nuance_to_groupe = {
    'UG' : 'Nouveau Front populaire',
    'EXG': 'Divers gauche',
    'COM': 'Divers gauche',
    'FI' : 'Divers gauche',
    'SOC': 'Divers gauche',
    'RDG': 'Divers gauche', 
    'VEC': 'Divers gauche', 
    'DVG': 'Divers gauche',
    'ECO': 'Divers gauche',
    'ENS': 'Ensemble',
    'REN': 'Ensemble',
    'MDM': 'Ensemble',
    'HOR': 'Ensemble',
    'UDI': 'Ensemble',
    'DVC': 'Divers centre',
    'LR' : 'Les Républicains',
    'DVD': 'Divers droite',
    'REC': 'Divers droite',
    'DSV': 'Divers droite',
    'EXD': 'Divers droite',
    'RN' : 'Rassemblement national',
    'UXD': 'Rassemblement national-Les Républicains',
    'REG': 'Régionalistes',
    'DIV': 'Autres'
    
}

t1_entete = (
    t1_resultats
    .assign(
        NbVoix = lambda df: df.NbVoix.astype(int)
    )
    .sort_values('NbVoix', ascending=False)
    .drop_duplicates('CodCirc2', keep='first')
    .set_index('CodCirc2')
    .sort_index()
    .assign(
        GrpLib = lambda df: df.CodNuaCand.apply(lambda x: nuance_to_groupe[x]),
        CandLib = lambda df: df.PrenomPsn+" "+df.NomPsn
    )
)

t1_entete.tail(30)
# Out:
#           NumPanneauCand        NomPsn    PrenomPsn CivilitePsn CodNuaCand  \
# CodCirc2
# ZC001                  1        CASTOR  Jean-Victor          M.        REG
# ZC002                  5        RIMANE         Davy          M.        REG
# ZD001                  1       NAILLET     Philippe          M.         UG
# ZD002                  5         LEBON       Karine         Mme         UG
# ZD003                  1       RIVIERE       Joseph          M.         RN
# ZD004                  2         KBIDI      Emeline         Mme        DVG
# ZD005                  5       RATENON  Jean-Hugues          M.        DVG
# ZD006                  3       MAILLOT     Frédéric          M.        DVG
# ZD007                  9      GAILLARD     Perceval          M.         UG
# ZM001                  2    YOUSSOUFFA      Estelle         Mme        DVD
# ZM002                  8        BAMANA       Anchya         Mme         RN
# ZN001                  2      METZDORF      Nicolas          M.        DVD
# ZN002                  2       TJIBAOU     Emmanuel          M.        REG
# ZP001                  3      FREBAULT      Moerani          M.        DVD
# ZP002                  1       SANQUER       Nicole         Mme        DVD
# ZP003                  3  REID ABERLOT      Mereana         Mme        REG
# ZS001                  1     LENORMAND     Stéphane          M.        DVD
# ZW001                  4           SEO      Mikaele          M.        ENS
# ZX001                  8         GUMBS       Frantz          M.        DVC
# ZZ001                  1       LESCURE       Roland          M.        ENS
# ZZ002                  7      CORONADO       Sergio          M.         UG
# ZZ003                  1     MINVIELLE    Charlotte         Mme         UG
# ZZ004                  2       GONDARD      Cécilia         Mme         UG
# ZZ005                  8       VOJETTA     Stéphane          M.        DVC
# ZZ006                  3      FERRACCI         Marc          M.        ENS
# ZZ007                  1         PETIT     Frédéric          M.        ENS
# ZZ008                  5         HABIB        Meyer          M.         LR
# ZZ009                  9    BEN CHEÏKH        Karim          M.         UG
# ZZ010                  6        DI MEO         Elsa         Mme         UG
# ZZ011                 13       GENETET         Anne         Mme        ENS
#
#                                     LibNuaCand  NbVoix RapportExprimes  \
# CodCirc2
# ZC001                             Régionaliste   12895           62,78
# ZC002                             Régionaliste    8307           60,21
# ZD001                       Union de la gauche   19186           46,25
# ZD002                       Union de la gauche   19068           47,72
# ZD003                   Rassemblement National   13360           31,56
# ZD004                            Divers gauche   22696           42,28
# ZD005                            Divers gauche   11536           33,18
# ZD006                            Divers gauche   10818           29,76
# ZD007                       Union de la gauche   14851           29,55
# ZM001                            Divers droite   13640           79,48
# ZM002                   Rassemblement National    7933           35,42
# ZN001                            Divers droite   22316           39,81
# ZN002                             Régionaliste   32926           44,06
# ZP001                            Divers droite   18456           53,85
# ZP002                            Divers droite   12986           49,09
# ZP003                             Régionaliste   12483           42,71
# ZS001                            Divers droite    1184           43,09
# ZW001     Ensemble ! (Majorité présidentielle)    4281           62,25
# ZX001                            Divers centre    2867           41,44
# ZZ001     Ensemble ! (Majorité présidentielle)   36363           38,84
# ZZ002                       Union de la gauche    6952           36,16
# ZZ003                       Union de la gauche   26873           39,22
# ZZ004                       Union de la gauche   27898           37,45
# ZZ005                            Divers centre   14492           33,68
# ZZ006     Ensemble ! (Majorité présidentielle)   25590           40,54
# ZZ007     Ensemble ! (Majorité présidentielle)   21929           37,78
# ZZ008                         Les Républicains   11557           35,58
# ZZ009                       Union de la gauche   18505           51,57
# ZZ010                       Union de la gauche   11651           32,52
# ZZ011     Ensemble ! (Majorité présidentielle)   16770           39,94
#
#          RapportInscrits        Elu CodCirc CodDept  CodeReg  \
# CodCirc2
# ZC001              21,77  QUALIF T2   97301     973        3
# ZC002              16,73  QUALIF T2   97302     973        3
# ZD001              21,67  QUALIF T2   97401     974        4
# ZD002              18,74  QUALIF T2   97402     974        4
# ZD003              13,52  QUALIF T2   97403     974        4
# ZD004              20,36  QUALIF T2   97404     974        4
# ZD005              12,73  QUALIF T2   97405     974        4
# ZD006              12,76  QUALIF T2   97406     974        4
# ZD007              12,26  QUALIF T2   97407     974        4
# ZM001              29,87        OUI   97601     976        6
# ZM002              15,13  QUALIF T2   97602     976        6
# ZN001              22,97  QUALIF T2   98801     988        0
# ZN002              26,35  QUALIF T2   98802     988        0
# ZP001              25,02        OUI   98701     987        0
# ZP002              18,75  QUALIF T2   98702     987        0
# ZP003              18,08  QUALIF T2   98703     987        0
# ZS001              23,36  QUALIF T2   97501     975        0
# ZW001              47,40        OUI   98601     986        0
# ZX001              11,36  QUALIF T2    ZX01      ZX        0
# ZZ001              13,67  QUALIF T2    ZZ01      ZZ        0
# ZZ002               8,50  QUALIF T2    ZZ02      ZZ        0
# ZZ003              16,73  QUALIF T2    ZZ03      ZZ        0
# ZZ004              17,65  QUALIF T2    ZZ04      ZZ        0
# ZZ005              12,55  QUALIF T2    ZZ05      ZZ        0
# ZZ006              16,02  QUALIF T2    ZZ06      ZZ        0
# ZZ007              16,76  QUALIF T2    ZZ07      ZZ        0
# ZZ008               7,76  QUALIF T2    ZZ08      ZZ        0
# ZZ009              14,19  QUALIF T2    ZZ09      ZZ        0
# ZZ010              10,23  QUALIF T2    ZZ10      ZZ        0
# ZZ011              16,03  QUALIF T2    ZZ11      ZZ        0
#
#                         LibCirElec  NbSap  CodReg CodDpt  \
# CodCirc2
# ZC001         1ère circonscription      1       3    973
# ZC002         2ème circonscription      1       3    973
# ZD001         1ère circonscription      1       4    974
# ZD002         2ème circonscription      1       4    974
# ZD003         3ème circonscription      1       4    974
# ZD004         4ème circonscription      1       4    974
# ZD005         5ème circonscription      1       4    974
# ZD006         6ème circonscription      1       4    974
# ZD007         7ème circonscription      1       4    974
# ZM001         1ère circonscription      1       6    976
# ZM002         2ème circonscription      1       6    976
# ZN001         1ere circonscription      1       0    988
# ZN002         2ème circonscription      1       0    988
# ZP001         1ere circonscription      1       0    987
# ZP002         2ème circonscription      1       0    987
# ZP003         3ème circonscription      1       0    987
# ZS001     Saint-Pierre-et-Miquelon      1       0    975
# ZW001         1ère circonscription      1       0    986
# ZX001         1ère circonscription      1       0     ZX
# ZZ001         1ere circonscription      1       0     ZZ
# ZZ002         2ème circonscription      1       0     ZZ
# ZZ003         3ème circonscription      1       0     ZZ
# ZZ004         4ème circonscription      1       0     ZZ
# ZZ005         5ème circonscription      1       0     ZZ
# ZZ006         6ème circonscription      1       0     ZZ
# ZZ007         7ème circonscription      1       0     ZZ
# ZZ008         8ème circonscription      1       0     ZZ
# ZZ009         9ème circonscription      1       0     ZZ
# ZZ010        10ème circonscription      1       0     ZZ
# ZZ011        11ème circonscription      1       0     ZZ
#
#                            GrpLib               CandLib
# CodCirc2
# ZC001               Régionalistes    Jean-Victor CASTOR
# ZC002               Régionalistes           Davy RIMANE
# ZD001     Nouveau Front populaire      Philippe NAILLET
# ZD002     Nouveau Front populaire          Karine LEBON
# ZD003      Rassemblement national        Joseph RIVIERE
# ZD004               Divers gauche         Emeline KBIDI
# ZD005               Divers gauche   Jean-Hugues RATENON
# ZD006               Divers gauche      Frédéric MAILLOT
# ZD007     Nouveau Front populaire     Perceval GAILLARD
# ZM001               Divers droite    Estelle YOUSSOUFFA
# ZM002      Rassemblement national         Anchya BAMANA
# ZN001               Divers droite      Nicolas METZDORF
# ZN002               Régionalistes      Emmanuel TJIBAOU
# ZP001               Divers droite      Moerani FREBAULT
# ZP002               Divers droite        Nicole SANQUER
# ZP003               Régionalistes  Mereana REID ABERLOT
# ZS001               Divers droite    Stéphane LENORMAND
# ZW001                    Ensemble           Mikaele SEO
# ZX001               Divers centre          Frantz GUMBS
# ZZ001                    Ensemble        Roland LESCURE
# ZZ002     Nouveau Front populaire       Sergio CORONADO
# ZZ003     Nouveau Front populaire   Charlotte MINVIELLE
# ZZ004     Nouveau Front populaire       Cécilia GONDARD
# ZZ005               Divers centre      Stéphane VOJETTA
# ZZ006                    Ensemble         Marc FERRACCI
# ZZ007                    Ensemble        Frédéric PETIT
# ZZ008            Les Républicains           Meyer HABIB
# ZZ009     Nouveau Front populaire      Karim BEN CHEÏKH
# ZZ010     Nouveau Front populaire           Elsa DI MEO
# ZZ011                    Ensemble          Anne GENETET

# %%
lg2022_resultats = (
    pd
    .read_csv('lg2022_t2_resultats.csv')
    .assign(
        NbVoix = lambda df: df.NbVoix.astype(int)
    )
    .sort_values('NbVoix', ascending=False)
    .drop_duplicates('CodCirc2', keep='first')
    .pipe(lambda df: 
        pd.concat([
            df,
            pd
            .read_csv('lg2022_t1_resultats.csv')
            .query('Elu == "oui"')
        ])
    )
    .set_index('CodCirc2')
    .sort_index()
)

lg2022_resultats
# Out:
#           NumPanneauCand      NomPsn PrenomPsn CivilitePsn CodNua  \
# CodCirc2
# 01001                  3      BRETON    Xavier          M.     LR
# 01002                  2      DAUBIÉ    Romain          M.    ENS
# 01003                  3    GIVERNET      Olga         Mme    ENS
# 01004                  4     BUISSON    Jérôme          M.     RN
# 01005                  4        ABAD    Damien          M.    DVD
# ...                  ...         ...       ...         ...    ...
# ZZ007                  2       PETIT  Frédéric          M.    ENS
# ZZ008                  8       HABIB     Meyer          M.    UDI
# ZZ009                  3  BEN CHEÏKH     Karim          M.    NUP
# ZZ010                  4     LAKRAFI    Amélia         Mme    ENS
# ZZ011                  1     GENETET      Anne         Mme    ENS
#
#                                                   LibNua  NbVoix  \
# CodCirc2
# 01001                                   Les Républicains   24408
# 01002               Ensemble ! (Majorité présidentielle)   24960
# 01003               Ensemble ! (Majorité présidentielle)   18398
# 01004                             Rassemblement National   22601
# 01005                                      Divers droite   17687
# ...                                                  ...     ...
# ZZ007               Ensemble ! (Majorité présidentielle)   23191
# ZZ008           Union des Démocrates et des Indépendants    8470
# ZZ009     Nouvelle union populaire écologique et sociale   11348
# ZZ010               Ensemble ! (Majorité présidentielle)   13048
# ZZ011               Ensemble ! (Majorité présidentielle)   16537
#
#          RapportExprime RapportInscrit  Elu CodCirc CodCirc1
# CodCirc2
# 01001             63,22          28,32  oui   00101    00101
# 01002             58,34          24,97  oui   00102    00102
# 01003             58,72          22,38  oui   00103    00103
# 01004             62,27          23,81  oui   00104    00104
# 01005             57,86          22,83  oui   00105    00105
# ...                 ...            ...  ...     ...      ...
# ZZ007             60,21          18,79  oui   09907    09907
# ZZ008             50,58           6,46  oui   09908    09908
# ZZ009             54,07           9,41  oui   09909    09909
# ZZ010             63,58          12,49  oui   09910    09910
# ZZ011             61,73          16,73  oui   09911    09911
#
# [577 rows x 12 columns]

# %%
def get_resultats(CodCirc, CodDept, CodeReg, tour):
    url = f'{base}/resultatsT{tour}/{CodDept}/R{tour}{CodCirc}.xml'
    
    try:
        df = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]//Candidat',
                dtype = 'object'
            )
            .assign(
                CodCirc=CodCirc,
                CodDept=CodDept,
                CodeReg=CodeReg
            )
        )
        #print(url)
    except:
        #print(f'error: {circonscription}')
        df = None
        
    
    return df
    
    
resultats_t2 = (
    pd
    .concat([
        get_resultats(c['CodCirElec'], c['CodDpt'], c['CodReg'], 2)
        for idx, c in tqdm(list(circonscriptions.reset_index().iterrows()))
    ])
    .join(
        circonscriptions
        .reset_index()
        .assign(
            CodCirc2 = lambda df: (
                df.CodDpt.replace(mapping_dept)
                + df.CodCirElec.astype(str).str[-2:].str.pad(3, fillchar='0')
            )
        )
        .set_index('CodCirElec'), #[['CodCirc2']],
        on = 'CodCirc'
    )
    .query('Elu == "OUI"')
)
resultats_t2
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
#    NumPanneauCand        NomPsn        PrenomPsn CivilitePsn CodNuaCand  \
# 0               1     LENORMAND         Stéphane          M.        DVD
# 0               1       SANQUER           Nicole         Mme        DVD
# 0               3  REID ABERLOT          Mereana         Mme         UG
# 0               2      METZDORF          Nicolas          M.        DVD
# 0               2       TJIBAOU         Emmanuel          M.        REG
# ..            ...           ...              ...         ...        ...
# 0               1       RIMBERT        Catherine         Mme         RN
# 0               7    MARCANGELI          Laurent          M.        ENS
# 0               1     COLOMBANI       Paul-André          M.        REG
# 0               2    CASTELLANI           Michel          M.        REG
# 1               3       CECCOLI  François-Xavier          M.        DVD
#
#                               LibNuaCand NbVoix RapportExprimes  \
# 0                          Divers droite   1665           61,74
# 0                          Divers droite  17838           55,88
# 0                     Union de la gauche  17308           50,87
# 0                          Divers droite  34577           52,41
# 0                           Régionaliste  51724           57,44
# ..                                   ...    ...             ...
# 0                 Rassemblement National  29667           55,39
# 0   Ensemble ! (Majorité présidentielle)  20892           63,20
# 0                           Régionaliste  23969           59,21
# 0                           Régionaliste  24667           64,33
# 1                          Divers droite  24458           54,48
#
#    RapportInscrits  Elu CodCirc CodDept  CodeReg  index  \
# 0            32,85  OUI   97501     975        0      0
# 0            25,76  OUI   98702     987        0      3
# 0            25,07  OUI   98703     987        0      4
# 0            35,59  OUI   98801     988        0      5
# 0            41,40  OUI   98802     988        0      6
# ..             ...  ...     ...     ...      ...    ...
# 0            34,92  OUI    8405      84       93    572
# 0            39,80  OUI    2A01      2A       94    573
# 0            38,35  OUI    2A02      2A       94    574
# 0            39,71  OUI    2B01      2B       94    575
# 1            36,01  OUI    2B02      2B       94    576
#
#                   LibCirElec  NbSap  CodReg CodDpt CodCirc2
# 0   Saint-Pierre-et-Miquelon      1       0    975    ZS001
# 0       2ème circonscription      1       0    987    ZP002
# 0       3ème circonscription      1       0    987    ZP003
# 0       1ere circonscription      1       0    988    ZN001
# 0       2ème circonscription      1       0    988    ZN002
# ..                       ...    ...     ...    ...      ...
# 0       5ème circonscription      1      93     84    84005
# 0       1ère circonscription      1      94     2A    2A001
# 0       2ème circonscription      1      94     2A    2A002
# 0       1ère circonscription      1      94     2B    2B001
# 1       2ème circonscription      1      94     2B    2B002
#
# [501 rows x 19 columns]

# %%
t2_resultats = (
    resultats_t2
    .assign(
        NbVoix = lambda df: df.NbVoix.astype(int)
    )
    .sort_values('NbVoix', ascending=False)
    .drop_duplicates('CodCirc2', keep='first')
    .set_index('CodCirc2')
    .sort_index()
)

t2_resultats
# Out:
#          NumPanneauCand      NomPsn PrenomPsn CivilitePsn CodNuaCand  \
# CodCirc2
# 01001                 3      BRETON    Xavier          M.         LR
# 01002                 2      DAUBIÉ    Romain          M.        ENS
# 01003                 1    GIVERNET      Olga         Mme        ENS
# 01004                 6     BUISSON    Jérôme          M.         RN
# 01005                 8     CHAVENT      Marc          M.        UXD
# ...                 ...         ...       ...         ...        ...
# ZZ007                 1       PETIT  Frédéric          M.        ENS
# ZZ008                 6       YADAN  Caroline         Mme        ENS
# ZZ009                 9  BEN CHEÏKH     Karim          M.         UG
# ZZ010                 3     LAKRAFI    Amélia         Mme        ENS
# ZZ011                13     GENETET      Anne         Mme        ENS
#
#                                     LibNuaCand  NbVoix RapportExprimes  \
# CodCirc2
# 01001                         Les Républicains   33889           56,48
# 01002     Ensemble ! (Majorité présidentielle)   38973           55,09
# 01003     Ensemble ! (Majorité présidentielle)   32958           63,00
# 01004                   Rassemblement National   33186           51,35
# 01005                Union de l'extrême droite   27040           57,53
# ...                                        ...     ...             ...
# ZZ007     Ensemble ! (Majorité présidentielle)   34516           58,21
# ZZ008     Ensemble ! (Majorité présidentielle)   18302           52,70
# ZZ009                       Union de la gauche   26271           74,71
# ZZ010     Ensemble ! (Majorité présidentielle)   17055           53,23
# ZZ011     Ensemble ! (Majorité présidentielle)   21468           57,04
#
#          RapportInscrits  Elu CodCirc CodDept  CodeReg  index  \
# CodCirc2
# 01001              39,02  OUI    0101      01       84    467
# 01002              38,24  OUI    0102      01       84    468
# 01003              39,16  OUI    0103      01       84    469
# 01004              34,52  OUI    0104      01       84    470
# 01005              34,70  OUI    0105      01       84    471
# ...                  ...  ...     ...     ...      ...    ...
# ZZ007              26,39  OUI    ZZ07      ZZ        0     14
# ZZ008              12,29  OUI    ZZ08      ZZ        0     15
# ZZ009              20,15  OUI    ZZ09      ZZ        0     16
# ZZ010              14,98  OUI    ZZ10      ZZ        0     17
# ZZ011              20,52  OUI    ZZ11      ZZ        0     18
#
#                      LibCirElec  NbSap  CodReg CodDpt
# CodCirc2
# 01001      1ère circonscription      1      84     01
# 01002      2ème circonscription      1      84     01
# 01003      3ème circonscription      1      84     01
# 01004      4ème circonscription      1      84     01
# 01005      5ème circonscription      1      84     01
# ...                         ...    ...     ...    ...
# ZZ007      7ème circonscription      1       0     ZZ
# ZZ008      8ème circonscription      1       0     ZZ
# ZZ009      9ème circonscription      1       0     ZZ
# ZZ010     10ème circonscription      1       0     ZZ
# ZZ011     11ème circonscription      1       0     ZZ
#
# [501 rows x 18 columns]

# %%
t2_resultats.to_csv('tmp/t2_live.csv')

# %%
final_resultats = (
    pd
    .concat([
        t2_resultats
        .reset_index()
        .assign(
            Elu2 = lambda df: df.Elu
        ),
        t1_resultats
        .query('Elu == "OUI"')
        .assign(
            Elu1 = lambda df: df.Elu
        )
    ])
    .set_index('CodCirc2')
    .sort_index()
)

final_resultats
# Out:
#          NumPanneauCand      NomPsn PrenomPsn CivilitePsn CodNuaCand  \
# CodCirc2
# 01001                 3      BRETON    Xavier          M.         LR
# 01002                 2      DAUBIÉ    Romain          M.        ENS
# 01003                 1    GIVERNET      Olga         Mme        ENS
# 01004                 6     BUISSON    Jérôme          M.         RN
# 01005                 8     CHAVENT      Marc          M.        UXD
# ...                 ...         ...       ...         ...        ...
# ZZ007                 1       PETIT  Frédéric          M.        ENS
# ZZ008                 6       YADAN  Caroline         Mme        ENS
# ZZ009                 9  BEN CHEÏKH     Karim          M.         UG
# ZZ010                 3     LAKRAFI    Amélia         Mme        ENS
# ZZ011                13     GENETET      Anne         Mme        ENS
#
#                                     LibNuaCand  NbVoix RapportExprimes  \
# CodCirc2
# 01001                         Les Républicains   33889           56,48
# 01002     Ensemble ! (Majorité présidentielle)   38973           55,09
# 01003     Ensemble ! (Majorité présidentielle)   32958           63,00
# 01004                   Rassemblement National   33186           51,35
# 01005                Union de l'extrême droite   27040           57,53
# ...                                        ...     ...             ...
# ZZ007     Ensemble ! (Majorité présidentielle)   34516           58,21
# ZZ008     Ensemble ! (Majorité présidentielle)   18302           52,70
# ZZ009                       Union de la gauche   26271           74,71
# ZZ010     Ensemble ! (Majorité présidentielle)   17055           53,23
# ZZ011     Ensemble ! (Majorité présidentielle)   21468           57,04
#
#          RapportInscrits  Elu CodCirc CodDept  CodeReg  index  \
# CodCirc2
# 01001              39,02  OUI    0101      01       84  467.0
# 01002              38,24  OUI    0102      01       84  468.0
# 01003              39,16  OUI    0103      01       84  469.0
# 01004              34,52  OUI    0104      01       84  470.0
# 01005              34,70  OUI    0105      01       84  471.0
# ...                  ...  ...     ...     ...      ...    ...
# ZZ007              26,39  OUI    ZZ07      ZZ        0   14.0
# ZZ008              12,29  OUI    ZZ08      ZZ        0   15.0
# ZZ009              20,15  OUI    ZZ09      ZZ        0   16.0
# ZZ010              14,98  OUI    ZZ10      ZZ        0   17.0
# ZZ011              20,52  OUI    ZZ11      ZZ        0   18.0
#
#                      LibCirElec  NbSap  CodReg CodDpt Elu2 Elu1
# CodCirc2
# 01001      1ère circonscription      1      84     01  OUI  NaN
# 01002      2ème circonscription      1      84     01  OUI  NaN
# 01003      3ème circonscription      1      84     01  OUI  NaN
# 01004      4ème circonscription      1      84     01  OUI  NaN
# 01005      5ème circonscription      1      84     01  OUI  NaN
# ...                         ...    ...     ...    ...  ...  ...
# ZZ007      7ème circonscription      1       0     ZZ  OUI  NaN
# ZZ008      8ème circonscription      1       0     ZZ  OUI  NaN
# ZZ009      9ème circonscription      1       0     ZZ  OUI  NaN
# ZZ010     10ème circonscription      1       0     ZZ  OUI  NaN
# ZZ011     11ème circonscription      1       0     ZZ  OUI  NaN
#
# [577 rows x 20 columns]

# %%
final_resultats.to_csv('lg2024/t2_resultats.csv')

# %% [markdown]
# ## manquant

# %%
circonscriptions.loc[ ~circonscriptions.CodCirc2.isin(final_resultats.index)]
# Out:
# Empty DataFrame
# Columns: [CodCirElec, LibCirElec, NbSap, CodReg, CodDpt, CodCirc2]
# Index: []

# %%
export = (
    circonscriptions
    .reset_index()
    .assign(
        CodCirc2 = lambda df: (
            df.CodDpt.replace(mapping_dept)
            + df.CodCirElec.astype(str).str[-2:].str.pad(3, fillchar='0')
        )
    )
    .set_index('CodCirc2')[[]]
    .sort_index()
    .join(
        final_resultats
        .assign(
            GrpLib = lambda df: df.CodNuaCand.apply(lambda x: nuance_to_groupe[x]),
            CandLib = lambda df: df.PrenomPsn+" "+df.NomPsn
        )
        [['CandLib', 'CodNuaCand', 'LibNuaCand', 'GrpLib', 'Elu1','Elu2']]
    )
    .assign(
        Elu = lambda df: df.Elu1.replace({ "QUALIF T2": "", "NON": "" })
    )
    .join(
        lg2022_resultats
        .assign(
            SortantLabel = lambda df: df.PrenomPsn+" "+df.NomPsn+" - "+df.LibNua
        )
        [['SortantLabel']]
    )
    .fillna('')
)

export
# Out:
#                    CandLib CodNuaCand                            LibNuaCand  \
# CodCirc2
# 01001        Xavier BRETON         LR                      Les Républicains
# 01002        Romain DAUBIÉ        ENS  Ensemble ! (Majorité présidentielle)
# 01003        Olga GIVERNET        ENS  Ensemble ! (Majorité présidentielle)
# 01004       Jérôme BUISSON         RN                Rassemblement National
# 01005         Marc CHAVENT        UXD             Union de l'extrême droite
# ...                    ...        ...                                   ...
# ZZ007       Frédéric PETIT        ENS  Ensemble ! (Majorité présidentielle)
# ZZ008       Caroline YADAN        ENS  Ensemble ! (Majorité présidentielle)
# ZZ009     Karim BEN CHEÏKH         UG                    Union de la gauche
# ZZ010       Amélia LAKRAFI        ENS  Ensemble ! (Majorité présidentielle)
# ZZ011         Anne GENETET        ENS  Ensemble ! (Majorité présidentielle)
#
#                                            GrpLib Elu1 Elu2 Elu  \
# CodCirc2
# 01001                            Les Républicains       OUI
# 01002                                    Ensemble       OUI
# 01003                                    Ensemble       OUI
# 01004                      Rassemblement national       OUI
# 01005     Rassemblement national-Les Républicains       OUI
# ...                                           ...  ...  ...  ..
# ZZ007                                    Ensemble       OUI
# ZZ008                                    Ensemble       OUI
# ZZ009                     Nouveau Front populaire       OUI
# ZZ010                                    Ensemble       OUI
# ZZ011                                    Ensemble       OUI
#
#                                                SortantLabel
# CodCirc2
# 01001                      Xavier BRETON - Les Républicains
# 01002     Romain DAUBIÉ - Ensemble ! (Majorité président...
# 01003     Olga GIVERNET - Ensemble ! (Majorité président...
# 01004               Jérôme BUISSON - Rassemblement National
# 01005                           Damien ABAD - Divers droite
# ...                                                     ...
# ZZ007     Frédéric PETIT - Ensemble ! (Majorité présiden...
# ZZ008     Meyer HABIB - Union des Démocrates et des Indé...
# ZZ009     Karim BEN CHEÏKH - Nouvelle union populaire éc...
# ZZ010     Amélia LAKRAFI - Ensemble ! (Majorité présiden...
# ZZ011     Anne GENETET - Ensemble ! (Majorité présidenti...
#
# [577 rows x 8 columns]

# %%
export.to_csv('tmp/lg2024_t2_flourish.csv')

# %%
elus = final_resultats.groupby('CodNuaCand').count()[['Elu1', 'Elu2']].assign(Total=lambda df: df.Elu1+df.Elu2)

elus
# Out:
#             Elu1  Elu2  Total
# CodNuaCand
# DIV            0     1      1
# DVC            0     6      6
# DVD            2    25     27
# DVG            0    12     12
# ECO            0     1      1
# ENS            2   148    150
# EXD            1     0      1
# HOR            0     6      6
# LR             1    38     39
# REG            0     9      9
# RN            37    88    125
# SOC            0     2      2
# UDI            0     3      3
# UG            32   146    178
# UXD            1    16     17

# %%
(
    pd.concat([
        (
            t1_resultats
            .query('CodCirc2.isin(@t1_resultats.query("Elu == \'OUI\'").CodCirc2.unique())')
        ),
        t2_resultats
    ])
    .groupby('CodNuaCand')
    [['NbVoix']]
    .sum()
    .pipe(lambda df: df.assign(RapportExprimes = lambda df2: df2.NbVoix / df.NbVoix.sum()))
    .join(
        elus
        [['Total']],
        how='inner'
    )
    .assign(
        PctSieges = lambda df: df.Total / elus['Total'].sum(),
        EcartVoixSieges = lambda df: df.PctSieges - df.RapportExprimes,
        PctSiegesFinal = lambda df: df.Total / 577
    )
    .style
    .format(
        {
            'RapportExprimes': '{:,.2%}'.format,
            'PctSieges': '{:,.2%}'.format,
            'PctSiegesFinal': '{:,.2%}'.format,
            'EcartVoixSieges': '{:,.2%}'.format,
        },
        thousands = " "
    )
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_87a2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87a2c_level0_col0" class="col_heading level0 col0" >NbVoix</th>
#       <th id="T_87a2c_level0_col1" class="col_heading level0 col1" >RapportExprimes</th>
#       <th id="T_87a2c_level0_col2" class="col_heading level0 col2" >Total</th>
#       <th id="T_87a2c_level0_col3" class="col_heading level0 col3" >PctSieges</th>
#       <th id="T_87a2c_level0_col4" class="col_heading level0 col4" >EcartVoixSieges</th>
#       <th id="T_87a2c_level0_col5" class="col_heading level0 col5" >PctSiegesFinal</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CodNuaCand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87a2c_level0_row0" class="row_heading level0 row0" >DIV</th>
#       <td id="T_87a2c_row0_col0" class="data row0 col0" >37 496</td>
#       <td id="T_87a2c_row0_col1" class="data row0 col1" >0.20%</td>
#       <td id="T_87a2c_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_87a2c_row0_col3" class="data row0 col3" >0.17%</td>
#       <td id="T_87a2c_row0_col4" class="data row0 col4" >-0.03%</td>
#       <td id="T_87a2c_row0_col5" class="data row0 col5" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row1" class="row_heading level0 row1" >DVC</th>
#       <td id="T_87a2c_row1_col0" class="data row1 col0" >175 166</td>
#       <td id="T_87a2c_row1_col1" class="data row1 col1" >0.93%</td>
#       <td id="T_87a2c_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_87a2c_row1_col3" class="data row1 col3" >1.04%</td>
#       <td id="T_87a2c_row1_col4" class="data row1 col4" >0.11%</td>
#       <td id="T_87a2c_row1_col5" class="data row1 col5" >1.04%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row2" class="row_heading level0 row2" >DVD</th>
#       <td id="T_87a2c_row2_col0" class="data row2 col0" >835 486</td>
#       <td id="T_87a2c_row2_col1" class="data row2 col1" >4.44%</td>
#       <td id="T_87a2c_row2_col2" class="data row2 col2" >27</td>
#       <td id="T_87a2c_row2_col3" class="data row2 col3" >4.68%</td>
#       <td id="T_87a2c_row2_col4" class="data row2 col4" >0.24%</td>
#       <td id="T_87a2c_row2_col5" class="data row2 col5" >4.68%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row3" class="row_heading level0 row3" >DVG</th>
#       <td id="T_87a2c_row3_col0" class="data row3 col0" >391 217</td>
#       <td id="T_87a2c_row3_col1" class="data row3 col1" >2.08%</td>
#       <td id="T_87a2c_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_87a2c_row3_col3" class="data row3 col3" >2.08%</td>
#       <td id="T_87a2c_row3_col4" class="data row3 col4" >-0.00%</td>
#       <td id="T_87a2c_row3_col5" class="data row3 col5" >2.08%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row4" class="row_heading level0 row4" >ECO</th>
#       <td id="T_87a2c_row4_col0" class="data row4 col0" >70 695</td>
#       <td id="T_87a2c_row4_col1" class="data row4 col1" >0.38%</td>
#       <td id="T_87a2c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_87a2c_row4_col3" class="data row4 col3" >0.17%</td>
#       <td id="T_87a2c_row4_col4" class="data row4 col4" >-0.20%</td>
#       <td id="T_87a2c_row4_col5" class="data row4 col5" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row5" class="row_heading level0 row5" >ENS</th>
#       <td id="T_87a2c_row5_col0" class="data row5 col0" >5 485 269</td>
#       <td id="T_87a2c_row5_col1" class="data row5 col1" >29.16%</td>
#       <td id="T_87a2c_row5_col2" class="data row5 col2" >150</td>
#       <td id="T_87a2c_row5_col3" class="data row5 col3" >26.00%</td>
#       <td id="T_87a2c_row5_col4" class="data row5 col4" >-3.17%</td>
#       <td id="T_87a2c_row5_col5" class="data row5 col5" >26.00%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row6" class="row_heading level0 row6" >EXD</th>
#       <td id="T_87a2c_row6_col0" class="data row6 col0" >24 267</td>
#       <td id="T_87a2c_row6_col1" class="data row6 col1" >0.13%</td>
#       <td id="T_87a2c_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_87a2c_row6_col3" class="data row6 col3" >0.17%</td>
#       <td id="T_87a2c_row6_col4" class="data row6 col4" >0.04%</td>
#       <td id="T_87a2c_row6_col5" class="data row6 col5" >0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row7" class="row_heading level0 row7" >HOR</th>
#       <td id="T_87a2c_row7_col0" class="data row7 col0" >187 374</td>
#       <td id="T_87a2c_row7_col1" class="data row7 col1" >1.00%</td>
#       <td id="T_87a2c_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_87a2c_row7_col3" class="data row7 col3" >1.04%</td>
#       <td id="T_87a2c_row7_col4" class="data row7 col4" >0.04%</td>
#       <td id="T_87a2c_row7_col5" class="data row7 col5" >1.04%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row8" class="row_heading level0 row8" >LR</th>
#       <td id="T_87a2c_row8_col0" class="data row8 col0" >1 388 871</td>
#       <td id="T_87a2c_row8_col1" class="data row8 col1" >7.38%</td>
#       <td id="T_87a2c_row8_col2" class="data row8 col2" >39</td>
#       <td id="T_87a2c_row8_col3" class="data row8 col3" >6.76%</td>
#       <td id="T_87a2c_row8_col4" class="data row8 col4" >-0.63%</td>
#       <td id="T_87a2c_row8_col5" class="data row8 col5" >6.76%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row9" class="row_heading level0 row9" >REG</th>
#       <td id="T_87a2c_row9_col0" class="data row9 col0" >248 860</td>
#       <td id="T_87a2c_row9_col1" class="data row9 col1" >1.32%</td>
#       <td id="T_87a2c_row9_col2" class="data row9 col2" >9</td>
#       <td id="T_87a2c_row9_col3" class="data row9 col3" >1.56%</td>
#       <td id="T_87a2c_row9_col4" class="data row9 col4" >0.24%</td>
#       <td id="T_87a2c_row9_col5" class="data row9 col5" >1.56%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row10" class="row_heading level0 row10" >RN</th>
#       <td id="T_87a2c_row10_col0" class="data row10 col0" >3 888 821</td>
#       <td id="T_87a2c_row10_col1" class="data row10 col1" >20.68%</td>
#       <td id="T_87a2c_row10_col2" class="data row10 col2" >125</td>
#       <td id="T_87a2c_row10_col3" class="data row10 col3" >21.66%</td>
#       <td id="T_87a2c_row10_col4" class="data row10 col4" >0.99%</td>
#       <td id="T_87a2c_row10_col5" class="data row10 col5" >21.66%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row11" class="row_heading level0 row11" >SOC</th>
#       <td id="T_87a2c_row11_col0" class="data row11 col0" >25 311</td>
#       <td id="T_87a2c_row11_col1" class="data row11 col1" >0.13%</td>
#       <td id="T_87a2c_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_87a2c_row11_col3" class="data row11 col3" >0.35%</td>
#       <td id="T_87a2c_row11_col4" class="data row11 col4" >0.21%</td>
#       <td id="T_87a2c_row11_col5" class="data row11 col5" >0.35%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row12" class="row_heading level0 row12" >UDI</th>
#       <td id="T_87a2c_row12_col0" class="data row12 col0" >116 219</td>
#       <td id="T_87a2c_row12_col1" class="data row12 col1" >0.62%</td>
#       <td id="T_87a2c_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_87a2c_row12_col3" class="data row12 col3" >0.52%</td>
#       <td id="T_87a2c_row12_col4" class="data row12 col4" >-0.10%</td>
#       <td id="T_87a2c_row12_col5" class="data row12 col5" >0.52%</td>
#     </tr>
#     <tr>
#       <th id="T_87a2c_level0_row13" class="row_heading level0 row13" >UG</th>
#       <td id="T_87a2c_row13_col0" class="data row13 col0" >5 391 460</td>
#       <td id="T_87a2c_row13_col1" class="data row13 col1" >28.66%</td>
#       <td id="T_87a2c_row13_col2" class="data row13 col2" >178</td>
#       <td id="T_87a2c_row13_col3" class="data row13 col3" >30.85%</td>
#       <td id="T_87a2c_row13_col4" class="data row13 col4" >2.1

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2024, 7, 8, 1, 53, 10, 680201)
