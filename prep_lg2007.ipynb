# %%
import pandas as pd
from tqdm.notebook import tqdm
import requests
import re

# %%
base = 'https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/'

# %%
departements = (
    pd
    .read_xml(
        f'{base}resultatsT1/index.xml',
        xpath='.//Dpt',
        encoding='latin1',
        dtype="object"
    )
)

departements
# Out:
#     CodReg CodReg3Car CodDpt CodDpt3Car CodMinDpt                    LibDpt  \
# 0       82        082     01        001        01                       AIN
# 1       22        022     02        002        02                     AISNE
# 2       83        083     03        003        03                    ALLIER
# 3       93        093     04        004        04   ALPES DE HAUTE PROVENCE
# 4       93        093     05        005        05              HAUTES ALPES
# ..     ...        ...    ...        ...       ...                       ...
# 100    000        000     ZM        976       976                   MAYOTTE
# 101    000        000     ZN        988       988        NOUVELLE CALEDONIE
# 102    000        000     ZP        987       987       POLYNESIE FRANCAISE
# 103    000        000     ZS        975       975  SAINT PIERRE ET MIQUELON
# 104    000        000     ZW        986       986          WALLIS-ET-FUTUNA
#
#     DateClotureDpt HeureClotureDpt  Clos
# 0       05-03-2012        14:41:02  CLOS
# 1       05-03-2012        14:41:02  CLOS
# 2       05-03-2012        14:41:02  CLOS
# 3       05-03-2012        14:41:02  CLOS
# 4       05-03-2012        14:41:02  CLOS
# ..             ...             ...   ...
# 100     05-03-2012        14:41:02  CLOS
# 101     05-03-2012        14:41:02  CLOS
# 102     05-03-2012        14:41:02  CLOS
# 103     05-03-2012        14:41:02  CLOS
# 104     05-03-2012        14:41:02  CLOS
#
# [105 rows x 9 columns]

# %%
circonscriptions = (
    pd.concat(
        [
            pd
            .read_xml(
                f'{base}resultatsT1/{c["CodDpt3Car"]}/{c["CodDpt3Car"]}cir.xml',
                xpath='.//Circonscription',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodDpt3Car = c['CodDpt3Car']
            )
            for idx, c in tqdm(list(departements.iterrows()))
        ]
    )
)

circonscriptions
# Out:
#   0%|          | 0/105 [00:00<?, ?it/s]
#    CodCirLg  Tour CodDpt3Car
# 0        01  None        001
# 1        02  None        001
# 2        03  None        001
# 3        04  None        001
# 0        01  None        002
# ..      ...   ...        ...
# 1        02  None        988
# 0        01  None        987
# 1        02  None        987
# 0        01  None        975
# 0        01  None        986
#
# [577 rows x 3 columns]

# %%
def get_tour(c, tour):
    results = None
    url = f'{base}resultatsT{tour}/{c.CodDpt3Car}/{c.CodDpt3Car}{c.CodCirLg}.xml'
    try:
        results = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]//Candidat',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodCirc = c['CodDpt3Car'] + c['CodCirLg'],
                NbVoix = lambda df: df.NbVoix.str.replace(' ','').astype(int),
                RapportExprimes = lambda df: df.RapportExprime.str.replace(' ','').str.replace(',','.').astype(float),
                RapportInscrits = lambda df: df.RapportInscrit.str.replace(' ','').str.replace(',','.').astype(float)
            )
        )
    except:
        print('error', url)
    
    return results

t1_resultats = (
    pd.concat(
        [
            get_tour(c,1)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t1_resultats
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
#              NomPsn       PrenomPsn CivilitePsn CodNua  \
# 0             DUTHU         Monique         Mme    VEC
# 1          CATHERIN  Marie-Lucienne         Mme     FN
# 2             DEBAT   Jean-François          M.    SOC
# 3             HURET           Odile         Mme    DIV
# 4   GUENARD-GERBAUD          Carole         Mme    EXG
# ..              ...             ...         ...    ...
# 0          LIKUVALU          Albert          M.    SOC
# 1             BRIAL          Victor          M.    UMP
# 2            ILALIO          Atonio          M.   UDFD
# 3           TAPUTAI        Pesamino          M.   UDFD
# 4            SIMETE     Erménégilde          M.    DVD
#
#                                LibNua  NbVoix RapportExprime RapportInscrit  \
# 0                           Les Verts    1411           2,75           1,62
# 1                      Front national    2086           4,06           2,40
# 2                          Socialiste   16415          31,98          18,95
# 3                              Divers     448           0,87           0,51
# 4                      Extrême gauche    1162           2,26           1,34
# ..                                ...     ...            ...            ...
# 0                          Socialiste    2424          31,14          21,72
# 1   Union pour un Mouvement Populaire    2625          33,72          23,52
# 2             UDF-Mouvement Démocrate     973          12,50           8,71
# 3             UDF-Mouvement Démocrate     661           8,49           5,92
# 4                       Divers droite    1101          14,14           9,86
#
#      Elu CodCirc  RapportExprimes  RapportInscrits
# 0    non   00101             2.75             1.62
# 1    non   00101             4.06             2.40
# 2   Bal.   00101            31.98            18.95
# 3    non   00101             0.87             0.51
# 4    non   00101             2.26             1.34
# ..   ...     ...              ...              ...
# 0   Bal.   98601            31.14            21.72
# 1   Bal.   98601            33.72            23.52
# 2    non   98601            12.50             8.71
# 3    non   98601             8.49             5.92
# 4    non   98601            14.14             9.86
#
# [7634 rows x 12 columns]

# %%
t1_resultats.to_csv('lg2007/t1_resultats.csv', index=False)

# %%
t2_resultats = (
    pd.concat(
        [
            get_tour(c,2)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t2_resultats
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/001/00102.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/001/00104.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/002/00202.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00602.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00603.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00604.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00605.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00606.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00607.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/006/00609.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/008/00803.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/010/01003.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/013/01302.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/013/01306.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/013/01309.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/013/01312.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/014/01404.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/015/01502.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/017/01704.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/017/01705.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/02A/02A02.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/021/02104.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/021/02105.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/025/02505.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/027/02703.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/028/02804.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/035/03505.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/038/03807.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/039/03901.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/042/04207.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/043/04301.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/045/04504.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/048/04802.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/049/04903.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/049/04904.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/049/04907.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/051/05105.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/051/05106.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/052/05201.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/052/05202.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/053/05303.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/057/05703.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/057/05704.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/057/05705.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/057/05707.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/059/05909.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/059/05914.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/059/05921.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/060/06004.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/060/06005.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/060/06007.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/061/06102.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/061/06103.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/062/06208.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/067/06704.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/067/06705.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/067/06706.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/067/06707.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/067/06708.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/067/06709.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/068/06802.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/068/06803.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/068/06804.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/068/06806.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/068/06807.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/069/06905.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/069/06908.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/069/06909.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/070/07001.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/070/07003.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/072/07204.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/073/07301.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/073/07302.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/074/07401.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/074/07403.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/074/07404.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/075/07503.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/075/07504.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/075/07514.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/075/07515.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/075/07516.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/076/07612.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/077/07704.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/077/07706.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/078/07802.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/078/07803.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/078/07804.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/078/07805.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/078/07806.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/078/07809.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/079/07903.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/083/08301.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/083/08302.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/083/08303.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/083/08305.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/083/08306.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/083/08307.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/085/08503.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/085/08504.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/085/08505.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/088/08801.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/088/08803.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/091/09102.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/091/09108.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/092/09203.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/092/09206.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/092/09207.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/092/09208.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/092/09209.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2007/resultatsT2/094/09408.xml

# %%
t2_resultats.to_csv('lg2007/t2_resultats.csv', index=False)

# %%
def get_inscrits(c, tour):
    results = None
    url = f'{base}resultatsT{tour}/{c.CodDpt3Car}/{c.CodDpt3Car}{c.CodCirLg}.xml'
    try:
        results = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]/Mentions/Inscrits',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodCirc = c['CodDpt3Car'] + c['CodCirLg'],
            #     # NbVoix = lambda df: df.NbVoix.str.replace(' ','').astype(int),
            #     # RapportExprimes = lambda df: df.RapportExprime.str.replace(' ','').str.replace(',','.').astype(float),
            #     # RapportInscrits = lambda df: df.RapportInscrit.str.replace(' ','').str.replace(',','.').astype(float)
            )
            .rename({'Nombre': 'Inscrits'}, axis=1)
        )
    except e:
        print('error', url)
        print(e)
    
    return results

t1_inscrits = (
    pd.concat(
        [
            get_inscrits(c,1)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t1_inscrits

# %%
t1_inscrits.to_csv('lg2007/t1_inscrits.csv', index=False)
