# %%
import pandas as pd
from tqdm.notebook import tqdm
import requests
import re

# %%
base = 'https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2017/'

# %%
departements = (
    pd
    .read_xml(
        f'{base}resultatsT1/index.xml',
        xpath='.//Departement',
        #encoding='latin1',
        dtype="object"
    )
)

departements
# Out:
#     CodDpt CodMinDpt CodDpt3Car                           LibDpt  DateDerMaj  \
# 0       01        01        001                              Ain  12-06-2017
# 1       02        02        002                            Aisne  11-06-2017
# 2       03        03        003                           Allier  12-06-2017
# 3       04        04        004          Alpes-de-Haute-Provence  12-06-2017
# 4       05        05        005                     Hautes-Alpes  12-06-2017
# ..     ...       ...        ...                              ...         ...
# 102     ZX       977        977    Saint-Martin/Saint-Barthélemy  11-06-2017
# 103     ZW       986        986                 Wallis et Futuna  11-06-2017
# 104     ZP       987        987              Polynésie française  07-06-2017
# 105     ZN       988        988               Nouvelle-Calédonie  11-06-2017
# 106     ZZ        99        099  Français établis hors de France  07-06-2017
#
#     HeureDerMaj DateDerExtract HeureDerExtract Complet
# 0      12:49:01     26-06-2017        10:04:10       O
# 1      21:40:40     26-06-2017        10:04:14       O
# 2      10:17:04     26-06-2017        10:04:14       O
# 3      11:47:57     26-06-2017        10:04:16       O
# 4      11:40:19     26-06-2017        10:04:19       O
# ..          ...            ...             ...     ...
# 102    17:24:44     26-06-2017        10:14:26       O
# 103    15:10:40     26-06-2017        10:14:26       O
# 104    00:09:13     26-06-2017        10:14:41       O
# 105    18:24:49     26-06-2017        10:14:42       O
# 106    17:01:55     26-06-2017        10:14:49       O
#
# [107 rows x 9 columns]

# %%
circonscriptions = (
    pd.concat(
        [
            pd
            .read_xml(
                f'{base}resultatsT1/{c["CodDpt3Car"]}/{c["CodDpt3Car"]}CIR.xml',
                xpath='.//Circonscription',
                #encoding='latin1',
                dtype="object"
            )
            .assign(
                CodDpt3Car = c['CodDpt3Car']
            )
            for idx, c in tqdm(list(departements.iterrows()))
        ]
    )
)

circonscriptions
# Out:
#   0%|          | 0/107 [00:00<?, ?it/s]
#    CodCirLg         Tours CodDpt3Car
# 0        01  \n                  001
# 1        02  \n                  001
# 2        03  \n                  001
# 3        04  \n                  001
# 4        05  \n                  001
# ..      ...           ...        ...
# 6        07  \n                  099
# 7        08  \n                  099
# 8        09  \n                  099
# 9        10  \n                  099
# 10       11  \n                  099
#
# [577 rows x 3 columns]

# %%
def get_tour(c, tour):
    results = None
    url = f'{base}resultatsT{tour}/{c.CodDpt3Car}/{c.CodDpt3Car}{c.CodCirLg}.xml'
    try:
        results = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]//Candidat',
                dtype="object"
            )
            .assign(
                CodCirc = c['CodDpt3Car'] + c['CodCirLg'],
                NbVoix = lambda df: df.NbVoix.str.replace(' ','').astype(int),
                RapportExprimes = lambda df: df.RapportExprime.str.replace(' ','').str.replace(',','.').astype(float),
                RapportInscrits = lambda df: df.RapportInscrit.str.replace(' ','').str.replace(',','.').astype(float)
            )
        )
    except:
        print('error', url)
    
    return results

t1_resultats = (
    pd.concat(
        [
            get_tour(c,1)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t1_resultats
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
#    NumPanneauCand          NomPsn  PrenomPsn CivilitePsn CodNua  \
# 0               1          MALLET    Laurent          M.    MDM
# 1               2  BLATRIX-CONTAT   Florence         Mme    SOC
# 2               3        LÉPAGNOT      Maude         Mme    EXG
# 3               4   MARTIN ZEMLIK    Fabrine         Mme     FI
# 4               5          BRETON     Xavier          M.     LR
# ..            ...             ...        ...         ...    ...
# 9              10          AGUIAR   Jennifer         Mme    DIV
# 10             11           ALNET     Myriem         Mme    DIV
# 11             12       NESENSHON   Frédéric          M.    DVD
# 12             13         COCHARD  Sébastien          M.     FN
# 13             14         GENETET       Anne         Mme    REM
#
#                      LibNua  NbVoix RapportExprime RapportInscrit   Elu  \
# 0                     Modem   13534          33,89          16,37  Bal.
# 1          Parti socialiste    3687           9,23           4,46   non
# 2            Extrême gauche     293           0,73           0,35   non
# 3       La France insoumise    3874           9,70           4,68   non
# 4          Les Républicains   10693          26,78          12,93  Bal.
# ..                      ...     ...            ...            ...   ...
# 9                    Divers     192           0,76           0,21   non
# 10                   Divers      74           0,29           0,08   non
# 11            Divers droite      92           0,36           0,10   non
# 12           Front National     733           2,89           0,79   non
# 13  La République en marche   13732          54,11          14,80  Bal.
#
#    CodCirc  RapportExprimes  RapportInscrits
# 0    00101            33.89            16.37
# 1    00101             9.23             4.46
# 2    00101             0.73             0.35
# 3    00101             9.70             4.68
# 4    00101            26.78            12.93
# ..     ...              ...              ...
# 9    09911             0.76             0.21
# 10   09911             0.29             0.08
# 11   09911             0.36             0.10
# 12   09911             2.89             0.79
# 13   09911            54.11            14.80
#
# [7877 rows x 13 columns]

# %%
t1_resultats.to_csv('lg2017/t1_resultats.csv', index=False)

# %%
t2_resultats = (
    pd.concat(
        [
            get_tour(c,2)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t2_resultats
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2017/resultatsT2/056/05604.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2017/resultatsT2/075/07501.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2017/resultatsT2/080/08005.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2017/resultatsT2/986/98601.xml
#    NumPanneauCand             NomPsn     PrenomPsn CivilitePsn CodNua  \
# 0               1             MALLET       Laurent          M.    MDM
# 1               5             BRETON        Xavier          M.     LR
# 0               6             BEGUET  Marie Jeanne         Mme    MDM
# 1               8  DE LA VERPILLIÈRE       Charles          M.     LR
# 0               4           GIVERNET          Olga         Mme    REM
# ..            ...                ...           ...         ...    ...
# 1              25              AÏCHI         Leila         Mme    DVD
# 0               6            LAKRAFI   Amal Amélia         Mme    REM
# 1               9            MARSAUD         Alain          M.     LR
# 0               9            MARIANI       Thierry          M.     LR
# 1              14            GENETET          Anne         Mme    REM
#
#                      LibNua  NbVoix RapportExprime RapportInscrit  Elu  \
# 0                     Modem   15114          46,25          18,28  non
# 1          Les Républicains   17564          53,75          21,25  oui
# 0                     Modem   17319          48,28          18,52  non
# 1          Les Républicains   18556          51,72          19,84  oui
# 0   La République en marche   16552          61,86          21,91  oui
# ..                      ...     ...            ...            ...  ...
# 1             Divers droite    4491          40,34           4,17  non
# 0   La République en marche   12397          71,25          12,40  oui
# 1          Les Républicains    5002          28,75           5,00  non
# 0          Les Républicains    5676          28,28           6,12  non
# 1   La République en marche   14397          71,72          15,52  oui
#
#    CodCirc  RapportExprimes  RapportInscrits
# 0    00101            46.25            18.28
# 1    00101            53.75            21.25
# 0    00102            48.28            18.52
# 1    00102            51.72            19.84
# 0    00103            61.86            21.91
# ..     ...              ...              ...
# 1    09909            40.34             4.17
# 0    09910            71.25            12.40
# 1    09910            28.75             5.00
# 0    09911            28.28             6.12
# 1    09911            71.72            15.52
#
# [1146 rows x 13 columns]

# %%
t2_resultats.to_csv('lg2017/t2_resultats.csv', index=False)

# %%
def get_inscrits(c, tour):
    results = None
    url = f'{base}resultatsT{tour}/{c.CodDpt3Car}/{c.CodDpt3Car}{c.CodCirLg}.xml'
    try:
        results = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]/Mentions/Inscrits',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodCirc = c['CodDpt3Car'] + c['CodCirLg'],
            #     # NbVoix = lambda df: df.NbVoix.str.replace(' ','').astype(int),
            #     # RapportExprimes = lambda df: df.RapportExprime.str.replace(' ','').str.replace(',','.').astype(float),
            #     # RapportInscrits = lambda df: df.RapportInscrit.str.replace(' ','').str.replace(',','.').astype(float)
            )
            .rename({'Nombre': 'Inscrits'}, axis=1)
        )
    except e:
        print('error', url)
        print(e)
    
    return results

t1_inscrits = (
    pd.concat(
        [
            get_inscrits(c,1)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t1_inscrits
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
#    Inscrits CodCirc
# 0     82694   00101
# 0     93520   00102
# 0     75614   00103
# 0     89390   00104
# 0     75359   00105
# ..      ...     ...
# 0    105955   09907
# 0    121399   09908
# 0    107796   09909
# 0     99374   09910
# 0     92766   09911
#
# [577 rows x 2 columns]

# %%
t1_inscrits.to_csv('lg2017/t1_inscrits.csv', index=False)
