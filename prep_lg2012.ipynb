# %%
import pandas as pd
from tqdm.notebook import tqdm
import requests
import re

# %%
base = 'https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/'

# %%
departements = (
    pd
    .read_xml(
        f'{base}resultatsT1/index.xml',
        xpath='.//Dpt',
        encoding='latin1',
        dtype="object"
    )
)

departements
# Out:
#     CodReg CodReg3Car CodDpt CodDpt3Car CodMinDpt  \
# 0       82        082     01        001        01
# 1       22        022     02        002        02
# 2       83        083     03        003        03
# 3       93        093     04        004        04
# 4       93        093     05        005        05
# ..     ...        ...    ...        ...       ...
# 102    000        000     ZP        987       987
# 103    000        000     ZS        975       975
# 104    000        000     ZW        986       986
# 105    000        000     ZX        977       977
# 106    000        000     ZZ        099        99
#
#                             LibDpt DateClotureDpt HeureClotureDpt  Clos
# 0                              AIN     12-06-2012        10:35:28  CLOS
# 1                            AISNE     12-06-2012        10:35:31  CLOS
# 2                           ALLIER     12-06-2012        10:35:32  CLOS
# 3          ALPES DE HAUTE PROVENCE     12-06-2012        10:35:33  CLOS
# 4                     HAUTES ALPES     12-06-2012        10:35:34  CLOS
# ..                             ...            ...             ...   ...
# 102            POLYNESIE FRANCAISE     12-06-2012        10:35:25  CLOS
# 103       SAINT PIERRE ET MIQUELON     12-06-2012        10:35:25  CLOS
# 104               WALLIS-ET-FUTUNA     12-06-2012        10:35:25  CLOS
# 105  SAINT-MARTIN/SAINT-BARTHELEMY     12-06-2012        10:35:26  CLOS
# 106         FRANCAIS DE L'ETRANGER     12-06-2012        10:35:26  CLOS
#
# [107 rows x 9 columns]

# %%
circonscriptions = (
    pd.concat(
        [
            pd
            .read_xml(
                f'{base}resultatsT1/{c["CodDpt3Car"]}/{c["CodDpt3Car"]}cir.xml',
                xpath='.//Circonscription',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodDpt3Car = c['CodDpt3Car']
            )
            for idx, c in tqdm(list(departements.iterrows()))
        ]
    )
)

circonscriptions
# Out:
#   0%|          | 0/107 [00:00<?, ?it/s]
#    CodCirLg  Tour CodDpt3Car
# 0        01  None        001
# 1        02  None        001
# 2        03  None        001
# 3        04  None        001
# 4        05  None        001
# ..      ...   ...        ...
# 6        07  None        099
# 7        08  None        099
# 8        09  None        099
# 9        10  None        099
# 10       11  None        099
#
# [577 rows x 3 columns]

# %%
def get_tour(c, tour):
    results = None
    url = f'{base}resultatsT{tour}/{c.CodDpt3Car}/{c.CodDpt3Car}{c.CodCirLg}.xml'
    try:
        results = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]//Candidat',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodCirc = c['CodDpt3Car'] + c['CodCirLg'],
                NbVoix = lambda df: df.NbVoix.str.replace(' ','').astype(int),
                RapportExprimes = lambda df: df.RapportExprime.str.replace(' ','').str.replace(',','.').astype(float),
                RapportInscrits = lambda df: df.RapportInscrit.str.replace(' ','').str.replace(',','.').astype(float)
            )
        )
    except:
        print('error', url)
    
    return results

t1_resultats = (
    pd.concat(
        [
            get_tour(c,1)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t1_resultats
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
#    NumPanneauCand     NomPsn  PrenomPsn CivilitePsn CodNua  \
# 0               1  ALLOUACHE      Nadia         Mme    VEC
# 1               2   LEPAGNOT      Maude         Mme    EXG
# 2               3   BAUDOUIN    Grégory          M.    DVD
# 3               4    FLECHON    Jacques          M.    DVD
# 4               5     PERRIN    Clément          M.     FN
# ..            ...        ...        ...         ...    ...
# 15             16    VILLARD       Marc          M.    SOC
# 16             17    BRETEAU  Sébastien          M.    DVD
# 17             18  BALLOUHEY     Claude          M.     FG
# 18             19    ARCIZET     Romain          M.    AUT
# 19             20    FAYOLLE  Jean-Loup          M.    AUT
#
#                        LibNua  NbVoix RapportExprime RapportInscrit   Elu  \
# 0   Europe-Ecologie-Les Verts    1161           2,47           1,46   non
# 1              Extrême gauche     141           0,30           0,17   non
# 2               Divers droite     296           0,63           0,37   non
# 3               Divers droite     220           0,47           0,27   non
# 4              Front National    7290          15,49           9,22   non
# ..                        ...     ...            ...            ...   ...
# 15                 Socialiste    5819          26,65           7,34  Bal.
# 16              Divers droite    1070           4,90           1,35   non
# 17            Front de gauche     403           1,85           0,50   non
# 18                     Autres     217           0,99           0,27   non
# 19                     Autres      78           0,36           0,09   non
#
#    CodCirc  RapportExprimes  RapportInscrits
# 0    00101             2.47             1.46
# 1    00101             0.30             0.17
# 2    00101             0.63             0.37
# 3    00101             0.47             0.27
# 4    00101            15.49             9.22
# ..     ...              ...              ...
# 15   09911            26.65             7.34
# 16   09911             4.90             1.35
# 17   09911             1.85             0.50
# 18   09911             0.99             0.27
# 19   09911             0.36             0.09
#
# [6603 rows x 13 columns]

# %%
t1_resultats.to_csv('lg2012/t1_resultats.csv', index=False)

# %%
t2_resultats = (
    pd.concat(
        [
            get_tour(c,2)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t2_resultats
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/006/00606.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/006/00607.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/008/00803.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/009/00901.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/015/01502.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/016/01601.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/016/01603.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/019/01901.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/024/02403.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/024/02404.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/028/02804.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/031/03108.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/032/03201.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/033/03303.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/033/03307.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/040/04003.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/044/04403.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/044/04404.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/044/04408.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/046/04602.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/050/05004.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/053/05303.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/062/06205.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/063/06304.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/064/06403.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/067/06706.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/067/06708.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/068/06803.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/075/07514.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/076/07604.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/079/07902.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/085/08504.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/971/97104.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/974/97402.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/974/97404.xml
# error https://www.archives-resultats-elections.interieur.gouv.fr/telechargements/LG2012/resultatsT2/975/97501.xml
#    NumPanneauCand             NomPsn      PrenomPsn CivilitePsn CodNua  \
# 0               1              DEBAT  Jean-François          M.    SOC
# 1               2             BRETON         Xavier          M.    UMP
# 0               1            RAYMOND         Michel          M.    DVG
# 1               2  DE LA VERPILLIERE        Charles          M.    UMP
# 2               3             EYRAUD        Olivier          M.     FN
# ..            ...                ...            ...         ...    ...
# 1               2          AMIRSHAHI         Pouria          M.    SOC
# 0               1             CHAOUI    Jean-Daniel          M.    SOC
# 1               2            MARSAUD          Alain          M.    UMP
# 0               1            MARIANI        Thierry          M.    UMP
# 1               2            VILLARD           Marc          M.    SOC
#
#                                LibNua  NbVoix RapportExprime RapportInscrit  \
# 0                          Socialiste   22743          48,41          28,76
# 1   Union pour un Mouvement Populaire   24233          51,59          30,64
# 0                       Divers gauche   19529          38,76          22,46
# 1   Union pour un Mouvement Populaire   22327          44,31          25,68
# 2                      Front National    8530          16,93           9,81
# ..                                ...     ...            ...            ...
# 1                          Socialiste   10851          62,39          11,17
# 0                          Socialiste    9631          46,87          10,54
# 1   Union pour un Mouvement Populaire   10919          53,13          11,95
# 0   Union pour un Mouvement Populaire   10390          52,15          13,16
# 1                          Socialiste    9532          47,85          12,08
#
#     Elu CodCirc  RapportExprimes  RapportInscrits
# 0   non   00101            48.41            28.76
# 1   oui   00101            51.59            30.64
# 0   non   00102            38.76            22.46
# 1   oui   00102            44.31            25.68
# 2   non   00102            16.93             9.81
# ..  ...     ...              ...              ...
# 1   oui   09909            62.39            11.17
# 0   non   09910            46.87            10.54
# 1   oui   09910            53.13            11.95
# 0   oui   09911            52.15            13.16
# 1   non   09911            47.85            12.08
#
# [1101 rows x 13 columns]

# %%
t2_resultats.to_csv('lg2012/t2_resultats.csv', index=False)

# %%
def get_inscrits(c, tour):
    results = None
    url = f'{base}resultatsT{tour}/{c.CodDpt3Car}/{c.CodDpt3Car}{c.CodCirLg}.xml'
    try:
        results = (
            pd
            .read_xml(
                url,
                xpath=f'.//Tour[./NumTour = {tour}]/Mentions/Inscrits',
                encoding='latin1',
                dtype="object"
            )
            .assign(
                CodCirc = c['CodDpt3Car'] + c['CodCirLg'],
            #     # NbVoix = lambda df: df.NbVoix.str.replace(' ','').astype(int),
            #     # RapportExprimes = lambda df: df.RapportExprime.str.replace(' ','').str.replace(',','.').astype(float),
            #     # RapportInscrits = lambda df: df.RapportInscrit.str.replace(' ','').str.replace(',','.').astype(float)
            )
            .rename({'Nombre': 'Inscrits'}, axis=1)
        )
    except e:
        print('error', url)
        print(e)
    
    return results

t1_inscrits = (
    pd.concat(
        [
            get_inscrits(c,1)
            for idx, c in tqdm(list(circonscriptions.iterrows()))
        ]
    )
)

t1_inscrits
# Out:
#   0%|          | 0/577 [00:00<?, ?it/s]
#    Inscrits CodCirc
# 0     79066   00101
# 0     86982   00102
# 0     69837   00103
# 0     84591   00104
# 0     73718   00105
# ..      ...     ...
# 0     89033   09907
# 0    109411   09908
# 0     96769   09909
# 0     91600   09910
# 0     79171   09911
#
# [577 rows x 2 columns]

# %%
t1_inscrits.to_csv('lg2012/t1_inscrits.csv', index=False)
